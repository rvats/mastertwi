# %%
def sum1(n):
    result = 0;
    for x in range(n+1):
        result+=x
    return result

# %%
sum1(10)
# Out:
# 55

# %%
def sum2(n):
    return (n*(n+1))/2

# %%
sum2(10)
# Out:
# 55.0

# %%
# %timeit sum1(100)
# Out:
# 4.83 µs ± 90.5 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit sum2(100)
# Out:
# 167 ns ± 2.25 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
