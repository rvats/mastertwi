# %% [markdown]
# ## Pandas demo from Jake Reback
# see https://github.com/jreback/PyDataNYC2015 or http://pandas.pydata.org/pandas-docs/version/0.17.1/style.html#Table-Styles

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
pd.options.display.max_rows=12
pd.options.display.width=80

# read a csv
df = pd.read_csv('~/seaborn-data/iris.csv',index_col=False)
# adjust column names
df.columns = df.columns.str.replace('\s+','_').str.lower()
# in pandas 0.17.1 and more : sample and style ... 
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if   (isinstance(val, (int,   float)) and val < 3) else 'black'
    return 'color: %s' % color

def highlight_max(s):
    '''
    highlight the maximum in a Series
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

cm = sns.light_palette("green", as_cmap=True)

(df
   .sample (n=7)
   .style
   .applymap(color_negative_red, subset=pd.IndexSlice[['sepal_width', 'petal_width']])
   .bar(subset=['sepal_length', 'petal_length'], color='#7F7FFF')
   .background_gradient(subset=['sepal_width', 'petal_width'], cmap=cm)
   .apply(highlight_max)
   .highlight_null(null_color='red')
)
# Out:
# <style  type="text/css" >
#     #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 57.1%, transparent 0%);
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row0_col1 {
#             color:  red;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 73.9%, transparent 0%);
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row0_col3 {
#             color:  red;
#             background-color:  #45a645;
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row0_col4 {
#             background-color:  yellow;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 38.1%, transparent 0%);
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row1_col1 {
#             color:  black;
#             background-color:  #72bf72;
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 71.7%, transparent 0%);
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row1_col3 {
#             color:  red;
#             background-color:  #45a645;
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row2_col0 {
#             width:  10em;
#              height:  80%;
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row2_col1 {
#             color:  black;
#             background-color:  #44a644;
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row2_col2 {
#             width:  10em;
#              height:  80%;
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row2_col3 {
#             color:  red;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 4.8%, transparent 0%);
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row3_col1 {
#             color:  black;
#             background-color:  #2e992e;
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row3_col2 {
#             width:  10em;
#              height:  80%;
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row3_col3 {
#             color:  red;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 76.2%, transparent 0%);
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row4_col1 {
#             color:  black;
#             background-color:  #5cb35c;
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 91.3%, transparent 0%);
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row4_col3 {
#             color:  red;
#             background-color:  #289628;
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row4_col4 {
#             background-color:  yellow;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 100.0%, transparent 0%);
#             background-color:  yellow;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row5_col1 {
#             color:  black;
#             background-color:  #178c17;
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 100.0%, transparent 0%);
#             background-color:  yellow;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row5_col3 {
#             color:  red;
#             background-color:  #008000;
#             background-color:  yellow;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row5_col4 {
#             background-color:  yellow;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 9.5%, transparent 0%);
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row6_col1 {
#             color:  black;
#             background-color:  #008000;
#             background-color:  yellow;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row6_col2 {
#             width:  10em;
#              height:  80%;
#             : ;
#             : ;
#         }    #T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row6_col3 {
#             color:  red;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#         }</style>
# <table id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >sepal_length</th>
#         <th class="col_heading level0 col1" >sepal_width</th>
#         <th class="col_heading level0 col2" >petal_length</th>
#         <th class="col_heading level0 col3" >petal_width</th>
#         <th class="col_heading level0 col4" >species</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0level0_row0" class="row_heading level0 row0" >123</th>
#         <td id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row0_col0" class="data row0 col0" >6.3</td>
#         <td id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row0_col1" class="data row0 col1" >2.7</td>
#         <td id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row0_col2" class="data row0 col2" >4.9</td>
#         <td id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row0_col3" class="data row0 col3" >1.8</td>
#         <td id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row0_col4" class="data row0 col4" >virginica</td>
#     </tr>    <tr>
#         <th id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0level0_row1" class="row_heading level0 row1" >70</th>
#         <td id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row1_col0" class="data row1 col0" >5.9</td>
#         <td id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row1_col1" class="data row1 col1" >3.2</td>
#         <td id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row1_col2" class="data row1 col2" >4.8</td>
#         <td id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row1_col3" class="data row1 col3" >1.8</td>
#         <td id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row1_col4" class="data row1 col4" >versicolor</td>
#     </tr>    <tr>
#         <th id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0level0_row2" class="row_heading level0 row2" >39</th>
#         <td id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row2_col0" class="data row2 col0" >5.1</td>
#         <td id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row2_col1" class="data row2 col1" >3.4</td>
#         <td id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row2_col2" class="data row2 col2" >1.5</td>
#         <td id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row2_col3" class="data row2 col3" >0.2</td>
#         <td id="T_371ad5de_8aa0_11e8_89f9_10f0059a29e0row2_col4" class="data row2 col4" >setosa</td>
#     </tr>    <tr>
#         <th id="T_371ad5d

# %%
# assign = define new temporary columns (like 'mutate' in R language)
(df
   .query('sepal_length > 5')
   .assign(sepal_ratio = lambda x: x.sepal_width / x.sepal_length,
           petal_ratio = lambda x: x.petal_width / x.petal_length)
   .plot
   .scatter(x='sepal_ratio', y='petal_ratio', figsize=(8,4))
)

# %%
# pipe = like '%>%' in R language
(df
   .query('sepal_length > 5')
   .assign(sepal_ratio = lambda x: x.sepal_width / x.sepal_length,
           petal_ratio = lambda x: x.petal_width / x.petal_length)
   .pipe(sns.pairplot, hue='species', size=1.5)
)

# %%
# Pandas interactive
import pandas as pd
import numpy as np

# create a df with random datas
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan

# interactive
from IPython.html import widgets
@widgets.interact
def f(h_neg=(0, 359, 1), h_pos=(0, 359), s=(0., 99.9), l=(0., 99.9)):
    return (df
             .style
             .background_gradient(
                cmap=sns.palettes.diverging_palette(
                     h_neg=h_neg, h_pos=h_pos, s=s, l=l, as_cmap=True)
             ).highlight_null()
           )
# Out:
# interactive(children=(IntSlider(value=179, description='h_neg', max=359), IntSlider(value=179, description='h_…

# %%
from IPython.display import HTML

def hover(hover_color="#ff0f99"):
    return dict(selector="tr:hover",
                props=[("background-color", "%s" % hover_color)])

styles = [
    hover(),
    dict(selector="th", props=[("font-size", "150%"),
                               ("text-align", "center")]),
    dict(selector="caption", props=[("caption-side", "bottom")])
]
html = (df.style.set_table_styles(styles)
          .set_caption("Hover to highlight."))
html
# Out:
# <style  type="text/css" >
#     #T_6810c730_8aa0_11e8_af26_10f0059a29e0 tr:hover {
#           background-color: #ff0f99;
#     }    #T_6810c730_8aa0_11e8_af26_10f0059a29e0 th {
#           font-size: 150%;
#           text-align: center;
#     }    #T_6810c730_8aa0_11e8_af26_10f0059a29e0 caption {
#           caption-side: bottom;
#     }</style>
# <table id="T_6810c730_8aa0_11e8_af26_10f0059a29e0" ><caption>Hover to highlight.</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >A</th>
#         <th class="col_heading level0 col1" >B</th>
#         <th class="col_heading level0 col2" >C</th>
#         <th class="col_heading level0 col3" >D</th>
#         <th class="col_heading level0 col4" >E</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6810c730_8aa0_11e8_af26_10f0059a29e0level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row0_col0" class="data row0 col0" >1</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row0_col1" class="data row0 col1" >1.32921</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row0_col2" class="data row0 col2" >nan</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row0_col3" class="data row0 col3" >-0.31628</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row0_col4" class="data row0 col4" >-0.99081</td>
#     </tr>    <tr>
#         <th id="T_6810c730_8aa0_11e8_af26_10f0059a29e0level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row1_col0" class="data row1 col0" >2</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row1_col1" class="data row1 col1" >-1.07082</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row1_col2" class="data row1 col2" >-1.43871</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row1_col3" class="data row1 col3" >0.564417</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row1_col4" class="data row1 col4" >0.295722</td>
#     </tr>    <tr>
#         <th id="T_6810c730_8aa0_11e8_af26_10f0059a29e0level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row2_col0" class="data row2 col0" >3</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row2_col1" class="data row2 col1" >-1.6264</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row2_col2" class="data row2 col2" >0.219565</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row2_col3" class="data row2 col3" >0.678805</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row2_col4" class="data row2 col4" >1.88927</td>
#     </tr>    <tr>
#         <th id="T_6810c730_8aa0_11e8_af26_10f0059a29e0level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row3_col0" class="data row3 col0" >4</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row3_col1" class="data row3 col1" >0.961538</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row3_col2" class="data row3 col2" >0.104011</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row3_col3" class="data row3 col3" >-0.481165</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row3_col4" class="data row3 col4" >0.850229</td>
#     </tr>    <tr>
#         <th id="T_6810c730_8aa0_11e8_af26_10f0059a29e0level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row4_col0" class="data row4 col0" >5</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row4_col1" class="data row4 col1" >1.45342</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row4_col2" class="data row4 col2" >1.05774</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row4_col3" class="data row4 col3" >0.165562</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row4_col4" class="data row4 col4" >0.515018</td>
#     </tr>    <tr>
#         <th id="T_6810c730_8aa0_11e8_af26_10f0059a29e0level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row5_col0" class="data row5 col0" >6</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row5_col1" class="data row5 col1" >-1.33694</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row5_col2" class="data row5 col2" >0.562861</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row5_col3" class="data row5 col3" >1.39285</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row5_col4" class="data row5 col4" >-0.063328</td>
#     </tr>    <tr>
#         <th id="T_6810c730_8aa0_11e8_af26_10f0059a29e0level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row6_col0" class="data row6 col0" >7</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row6_col1" class="data row6 col1" >0.121668</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row6_col2" class="data row6 col2" >1.2076</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row6_col3" class="data row6 col3" >-0.00204021</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row6_col4" class="data row6 col4" >1.6278</td>
#     </tr>    <tr>
#         <th id="T_6810c730_8aa0_11e8_af26_10f0059a29e0level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row7_col0" class="data row7 col0" >8</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row7_col1" class="data row7 col1" >0.354493</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row7_col2" class="data row7 col2" >1.03753</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row7_col3" class="data row7 col3" >-0.385684</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row7_col4" class="data row7 col4" >0.519818</td>
#     </tr>    <tr>
#         <th id="T_6810c730_8aa0_11e8_af26_10f0059a29e0level0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row8_col0" class="data row8 col0" >9</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row8_col1" class="data row8 col1" >1.68658</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row8_col2" class="data row8 col2" >-1.32596</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row8_col3" class="data row8 col3" >1.42898</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row8_col4" class="data row8 col4" >-2.08935</td>
#     </tr>    <tr>
#         <th id="T_6810c730_8aa0_11e8_af26_10f0059a29e0level0_row9" class="row_heading level0 row9" >9</th>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row9_col0" class="data row9 col0" >10</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row9_col1" class="data row9 col1" >-0.12982</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row9_col2" class="data row9 col2" >0.631523</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row9_col3" class="data row9 col3" >-0.586538</td>
#         <td id="T_6810c730_8aa0_11e8_af26_10f0059a29e0row9_col4" class="data row9 col4" >0.29072</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ## Usefull links
#
# ### Beginners Training Video: ["Brandon Rhodes - Pandas From The Ground Up - PyCon 2015 "](https://www.youtube.com/watch?v=5JnMutdy6Fw)
#
# ### Pandas [API reference](http://pandas.pydata.org/pandas-docs/stable/api.html)
